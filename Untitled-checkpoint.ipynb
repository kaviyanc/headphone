# %% [markdown]
# # library install

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # importing libraries

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # scraping website

# %%
url="https://www.flipkart.com/search?q=+wireless+headphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY|"

# %% [markdown]
# # response

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # parsing

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
headphones=soup.select(".s1Q9rs")

# %%
headphones
# Out:
# [<a class="s1Q9rs" href="/enacfire-tws-e005-wireless-bluetooth-earbuds-mini-1500mah-power-bank-charging-case-headset/p/itm441a0ad4cb3aa?pid=ACCGC85VVJHN9YUG&amp;lid=LSTACCGC85VVJHN9YUGM3EVB6&amp;marketplace=FLIPKART&amp;q=+wireless+headphones&amp;store=0pm%2Ffcn&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=cf166a30-9d7d-40ee-8c1c-8c9193a28c7f.ACCGC85VVJHN9YUG.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=k13vf3z0kw0000001648060395124&amp;qH=da27f02132082aba" rel="noopener noreferrer" target="_blank" title="Enacfire TWS E005 Wireless Bluetooth Earbuds MINI with 1500mAh Power Bank Charging Case Bluetooth Headset">Enacfire TWS E005 Wireless Bluetooth Earbuds MINI with ...</a>,
# ...

# %%
headphones_list=[]

# %%
for item in headphones:
    headphones_list.append(item.text)
    headphones_list

# %%
headphones_list
# Out:
# ['Enacfire TWS E005 Wireless Bluetooth Earbuds MINI with ...',
#  'boAt Airdopes 131 Bluetooth Headset',
#  'Oxhox Magnetic Bluetooth Headset with Mic Bluetooth Hea...',
#  'Boult Audio Airbass Z1 Bluetooth Headset',
#  'Avlokan Air Tune (Buds) True wireless Bluetooth headset...',
#  'DAYNEO TwsL21 Mini Wireless Bluetooth Headset / Earphon...',
#  'Truke Buds Q1 with Environmental Noise Cancellation(ENC...',
#  'Boult Audio AirBass Xpods TWS Earbuds with 20H Playtime...',
#  'Grostar TWS A6S ear buds True Wireless Earbuds A6S Blue...',
#  'boAt Airdopes 131 Bluetooth Headset',
#  'HOPPUP GRAND With Power Bank Function & Upto 75 Hours P...',
#  'Boult Audio Airbass Z1 Bluetooth Headset',
#  'Enacfire X12 Moonwalk TWS in ear Bluetooth Earbuds Head...',
#  'boAt 100 Wireless Neckband with BT 5.0 IPX4 Bluetooth H...',
#  'JBL T450BT Extra Bass with Voice Assistant Support Ligh...',
#  'Boult Audio AirBass Combuds Bluetooth Headset',
# ...

# %%
amount=soup.select('._30jeq3')

# %%
amount
# Out:
# [<div class="_30jeq3">₹549</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹113</div>,
#  <div class="_30jeq3">₹1,449</div>,
#  <div class="_30jeq3">₹389</div>,
#  <div class="_30jeq3">₹539</div>,
#  <div class="_30jeq3">₹1,049</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹749</div>,
#  <div class="_30jeq3">₹1,449</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹1,375</div>,
#  <div class="_30jeq3">₹1,949</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹1,949</div>,
#  <div class="_30jeq3">₹1,049</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹999</div>,
#  <div class="_30jeq3">₹309</div>,
#  <div class="_30jeq3">₹233</div>,
#  <div class="_30jeq3">₹1,749</div>,
#  <div class="_30jeq3">₹849</div>,
#  <div class="_30jeq3">₹1,249</div>,
#  <div class="_30jeq3">₹1,649</div>,
# ...

# %%
amount_value=[]

# %%
for item in amount:
    amount_value.append(item.text)
    amount_value

# %%
amount_value
# Out:
# ['₹549',
#  '₹1,249',
#  '₹113',
#  '₹1,449',
#  '₹389',
#  '₹539',
#  '₹1,049',
#  '₹1,249',
#  '₹499',
#  '₹1,249',
#  '₹749',
#  '₹1,449',
#  '₹499',
#  '₹1,375',
#  '₹1,949',
#  '₹1,249',
#  '₹1,949',
#  '₹1,049',
#  '₹1,249',
#  '₹999',
#  '₹309',
#  '₹233',
#  '₹1,749',
#  '₹849',
#  '₹1,249',
#  '₹1,649',
#  '₹1,249',
#  '₹125',
#  '₹529',
#  '₹1,749',
#  '₹1,699',
#  '₹949',
#  '₹899',
#  '₹1,949',
#  '₹1,249',
#  '₹349',
#  '₹3,249',
#  '₹1,249',
#  '₹1,549',
#  '₹221',
#  '₹949',
#  '₹1,249',
#  '₹899',
#  '₹113',
#  '₹1,049']

# %%
rating=soup.select('._3LWZlK')

# %%
rating
# Out:
# [<div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.8<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.7<img class="_1wB99o" src="..."/></div>,
# ...

# %%
value_rating=[]

# %%
for item in rating:
    value_rating.append(item.text)
    value_rating

# %%
value_rating
# Out:
# ['3.7',
#  '4.1',
#  '3.4',
#  '3.7',
#  '3.7',
#  '4',
#  '3.9',
#  '4.6',
#  '4.1',
#  '3.8',
#  '3.5',
#  '4',
#  '4.2',
#  '3.7',
#  '4.2',
#  '4',
#  '4.1',
#  '4',
#  '3.6',
#  '3.5',
#  '4.2',
#  '3.9',
#  '4.1',
#  '3.9',
#  '4.1',
#  '3.8',
#  '3.7',
#  '4.2',
#  '4.3',
#  '3.6',
#  '4.1',
#  '4.3',
#  '3.7',
#  '3.6',
#  '4.1',
#  '4',
#  '4',
#  '3.5',
#  '3.6',
#  '5',
#  '3',
#  '3.7',
#  '5',
#  '3',
#  '4.1',
#  '5',
#  '5',
#  '3.4',
#  '5',
#  '2',
#  '4',
#  '5',
#  '4']

# %%
import pandas as pd

# %%
headphones=pd.DataFrame(headphones_list,columns=["headphones_list"])

# %%
headphones
# Out:
#                                       headphones_list
# 0   Enacfire TWS E005 Wireless Bluetooth Earbuds M...
# 1                 boAt Airdopes 131 Bluetooth Headset
# 2   Oxhox Magnetic Bluetooth Headset with Mic Blue...
# 3            Boult Audio Airbass Z1 Bluetooth Headset
# 4   Avlokan Air Tune (Buds) True wireless Bluetoot...
# 5   DAYNEO TwsL21 Mini Wireless Bluetooth Headset ...
# 6   Truke Buds Q1 with Environmental Noise Cancell...
# 7   Boult Audio AirBass Xpods TWS Earbuds with 20H...
# 8   Grostar TWS A6S ear buds True Wireless Earbuds...
# 9                 boAt Airdopes 131 Bluetooth Headset
# 10  HOPPUP GRAND With Power Bank Function & Upto 7...
# 11           Boult Audio Airbass Z1 Bluetooth Headset
# 12  Enacfire X12 Moonwalk TWS in ear Bluetooth Ear...
# 13  boAt 100 Wireless Neckband with BT 5.0 IPX4 Bl...
# 14  JBL T450BT Extra Bass with Voice Assistant Sup...
# 15      Boult Audio AirBass Combuds Bluetooth Headset
# ...

# %%
headphones.to_csv('head.phone.csv')
